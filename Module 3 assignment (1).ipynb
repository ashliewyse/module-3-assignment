# %% [markdown]
# ## 7.4

# %%
things = ["mozzarella", "cinderella", "salmonella"]
things
# Out:
# ['mozzarella', 'cinderella', 'salmonella']

# %%
things[1] = things[1].capitalize()
things
# Out:
# ['mozzarella', 'Cinderella', 'salmonella']

# %% [markdown]
# ## 7.5

# %% [markdown]
# Yes, the element in the list changed because I reassigned the capitalized value back into the list.

# %% [markdown]
# ## 7.6

# %%
things[0] = things[0].upper()
things
# Out:
# ['MOZZARELLA', 'Cinderella', 'salmonella']

# %% [markdown]
# ## 7.7

# %%
del things[2]
things
# Out:
# ['MOZZARELLA', 'Cinderella']

# %%
def good():
    return ['Harry', 'Ron', 'Hermione']

# %%
good()
# Out:
# ['Harry', 'Ron', 'Hermione']

# %% [markdown]
# ## 9.1

# %%
def get_odds():
    for number in range(10):
        if number % 2 != 0:
            yield number

# %%
count = 0
for odd in get_odds():
    count += 1
    if count == 3:
        print(odd)
        break
# Out:
# 5
